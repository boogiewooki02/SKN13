# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            
        test_loss /= num_steps
        test_accuracy /= size
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()
    size = len(dataloader.dataset) 

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        pred = model(X)

        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model=True, 
        save_model_path=None, early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary',
        lr_scheduler=None):
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        ############ 1 epoch 학습 종료 -> LR 를 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            if val_loss < best_score_es: 
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:
                trigger_count += 1                
                if patience == trigger_count:
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Writing module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Writing module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Writing module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lr = nn.Linear(28*28, 10) # 입력 -> 출력
    
    def forward(self, X):
        X = nn.Flatten()(X)
        out = self.lr(X)
        return out

# %%
small_model = SmallModel().to(device)
summary(small_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 10]                 7,850
# ==========================================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.79
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.35
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss() # 다중분류의 loss 함수
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

# %%
train_loss_list, train_acc_list, valid_loss_list, valid_acc_list = fit(
    train_loader,
    test_loader,
    small_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    device=device,
    mode='multi'
)
# Out:
# Epoch[1/100] - Train loss: 0.48306 Train Accucracy: 0.87998 || Validation Loss: 0.45969 Validation Accuracy: 0.88810
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.37860 Train Accucracy: 0.90013 || Validation Loss: 0.35989 Validation Accuracy: 0.90770
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.33880 Train Accucracy: 0.90885 || Validation Loss: 0.32417 Validation Accuracy: 0.91150
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.31624 Train Accucracy: 0.91360 || Validation Loss: 0.30253 Validation Accuracy: 0.91670
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.30218 Train Accucracy: 0.91687 || Validation Loss: 0.29141 Validation Accuracy: 0.91880
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.29249 Train Accucracy: 0.91995 || Validation Loss: 0.28501 Validation Accuracy: 0.92060
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.28505 Train Accucracy: 0.92067 || Validation Loss: 0.27884 Validation Accuracy: 0.92210
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.27951 Train Accucracy: 0.92255 || Validation Loss: 0.27352 Validation Accuracy: 0.92340
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.27422 Train Accucracy: 0.92368 || Validation Loss: 0.26960 Validation Accuracy: 0.92340
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.27006 Train Accucracy: 0.92493 || Validation Loss: 0.26712 Validation Accuracy: 0.92510
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.26676 Train Accucracy: 0.92565 || Validation Loss: 0.26638 Validation Accuracy: 0.92470
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.26335 Train Accucracy: 0.92698 || Validation Loss: 0.26375 Validation Accuracy: 0.92630
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.26112 Train Accucracy: 0.92727 || Validation Loss: 0.26309 Validation Accuracy: 0.92570
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.25864 Train Accucracy: 0.92808 || Validation Loss: 0.26201 Validation Accuracy: 0.92630
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.25707 Train Accucracy: 0.92890 || Validation Loss: 0.26155 Validation Accuracy: 0.92650
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.25493 Train Accucracy: 0.92913 || Validation Loss: 0.26127 Validation Accuracy: 0.92710
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.25335 Train Accucracy: 0.92967 || Validation Loss: 0.26052 Validation Accuracy: 0.92710
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.25186 Train Accucracy: 0.93042 || Validation Loss: 0.26004 Validation Accuracy: 0.92760
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.25131 Train Accucracy: 0.92985 || Validation Loss: 0.26051 Validation Accuracy: 0.92600
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.25015 Train Accucracy: 0.93027 || Validation Loss: 0.25907 Validation Accuracy: 0.92710
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.24900 Train Accucracy: 0.93102 || Validation Loss: 0.25948 Validation Accuracy: 0.92650
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.24731 Train Accucracy: 0.93155 || Validation Loss: 0.25904 Validation Accuracy: 0.92730
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.24653 Train Accucracy: 0.93190 || Validation Loss: 0.25860 Validation Accuracy: 0.92770
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.24580 Train Accucracy: 0.93270 || Validation Loss: 0.25881 Validation Accuracy: 0.92820
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.24577 Train Accucracy: 0.93203 || Validation Loss: 0.25925 Validation Accuracy: 0.92750
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.24423 Train Accucracy: 0.93240 || Validation Loss: 0.25917 Validation Accuracy: 0.92720
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.24371 Train Accucracy: 0.93268 || Validation Loss: 0.25959 Validation Accuracy: 0.92860
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.24136 Train Accucracy: 0.93350 || Validation Loss: 0.25773 Validation Accuracy: 0.92740
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.24103 Train Accucracy: 0.93350 || Validation Loss: 0.25818 Validation Accuracy: 0.92750
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.24081 Train Accucracy: 0.93355 || Validation Loss: 0.25876 Validation Accuracy: 0.92740
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.24000 Train Accucracy: 0.93405 || Validation Loss: 0.25674 Validation Accuracy: 0.92810
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.24020 Train Accucracy: 0.93347 || Validation Loss: 0.25744 Validation Accuracy: 0.92790
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.23931 Train Accucracy: 0.93447 || Validation Loss: 0.25887 Validation Accuracy: 0.92610
# ====================================================================================================
# Epoch[34/100] - Train loss: 0.23865 Train Accucracy: 0.93483 || Validation Loss: 0.25825 Validation Accuracy: 0.92810
# ====================================================================================================
# Epoch[35/100] - Train loss: 0.23775 Train Accucracy: 0.93507 || Validation Loss: 0.25914 Validation Accuracy: 0.92700
# ====================================================================================================
# Epoch[36/100] - Train loss: 0.23714 Train Accucracy: 0.93510 || Validation Loss: 0.25899 Validation Accuracy: 0.92750
# ====================================================================================================
# Epoch[37/100] - Train loss: 0.23684 Train Accucracy: 0.93508 || Validation Loss: 0.25882 Validation Accuracy: 0.92720
# ====================================================================================================
# Epoch[38/100] - Train loss: 0.23684 Train Accucracy: 0.93507 || Validation Loss: 0.26017 Validation Accuracy: 0.92650
# ====================================================================================================
# Epoch[39/100] - Train loss: 0.23577 Train Accucracy: 0.93542 || Validation Loss: 0.25858 Validation Accuracy: 0.92760
# ====================================================================================================
# Epoch[40/100] - Train loss: 0.23575 Train Accucracy: 0.93540 || Validation Loss: 0.25972 Validation Accuracy: 0.92730
# ====================================================================================================
# Epoch[41/100] - Train loss: 0.23544 Train Accucracy: 0.93488 || Validation Loss: 0.25841 Validation Accuracy: 0.92840
# ====================================================================================================
# Early stopping: Epoch - 40
# 297.46553206443787 초

# %% [markdown]
# ## 큰모델

# %%
# nn.Sequential() -> layer block: 레이어 함수들을 묶어놓은 블록

s = nn.Sequential(
    nn.Linear(10, 20),
    nn.ReLU(),
    nn.Linear(20, 30),
    nn.ReLU()
)

i = torch.randn(5, 10, dtype=torch.float32)
o = s(i)
print(o.shape)
o
# Out:
# torch.Size([5, 30])
# tensor([[0.0000e+00, 0.0000e+00, 4.0390e-01, 1.2925e-01, 0.0000e+00, 0.0000e+00,
#          1.4662e-02, 1.0142e-01, 0.0000e+00, 4.6530e-01, 0.0000e+00, 2.6794e-01,
#          5.6710e-02, 1.9376e-01, 0.0000e+00, 0.0000e+00, 1.4133e-02, 0.0000e+00,
#          1.9933e-01, 5.5137e-01, 0.0000e+00, 4.8418e-01, 1.6650e-01, 5.1021e-01,
#          1.4910e-01, 1.0500e-01, 1.5454e-01, 0.0000e+00, 0.0000e+00, 7.7510e-03],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.6125e-01, 4.9663e-02, 0.0000e+00,
#          2.0409e-01, 0.0000e+00, 0.0000e+00, 3.0205e-01, 1.7689e-02, 3.4484e-01,
#          4.8291e-01, 0.0000e+00, 0.0000e+00, 4.5987e-01, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 5.5681e-01, 0.0000e+00, 4.9704e-01, 0.0000e+00, 3.6392e-01,
#          0.0000e+00, 1.9177e-01, 5.0551e-02, 8.9630e-02, 0.0000e+00, 3.1958e-01],
#         [0.0000e+00, 0.0000e+00, 3.8851e-01, 1.3873e-01, 0.0000e+00, 0.0000e+00,
#          3.4975e-01, 3.2900e-01, 1.6214e-01, 6.0074e-02, 0.0000e+00, 2.0560e-01,
#          2.1863e-01, 0.0000e+00, 2.1492e-01, 1.6630e-01, 0.0000e+00, 0.0000e+00,
#          2.6991e-01, 7.1065e-01, 0.0000e+00, 2.6766e-01, 2.0644e-01, 5.4984e-01,
#          0.0000e+00, 5.7825e-01, 8.7356e-02, 1.5794e-02, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 3.8781e-01, 4.4776e-01, 0.0000e+00, 0.0000e+00,
#          7.6201e-02, 4.2079e-01, 0.0000e+00, 9.1856e-02, 1.4881e-01, 3.8396e-01,
#          7.0010e-02, 2.9422e-01, 0.0000e+00, 0.0000e+00, 1.8852e-01, 0.0000e+00,
#          0.0000e+00, 4.1838e-01, 0.0000e+00, 3.2470e-01, 2.0594e-01, 3.8832e-01,
#          0.0000e+00, 2.9776e-01, 0.0000e+00, 0.0000e+00, 4.0025e-04, 0.0000e+00],
#         [1.8105e-01, 0.0000e+00, 1.5375e-01, 3.1487e-01, 0.0000e+00, 3.1387e-01,
#          0.0000e+00, 3.0012e-01, 1.4407e-01, 2.5404e-01, 0.0000e+00, 3.0158e-01,
#          1.5570e-02, 3.7323e-01, 0.0000e+00, 0.0000e+00, 1.8494e-01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 3.3022e-01, 3.0201e-01, 2.5260e-01,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 9.3114e-02, 0.0000e+00]],
#        grad_fn=<ReluBackward0>)

# %%
class BigModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU())
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU())
        self.out_block = nn.Linear(32, 10)

    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
big_model = BigModel().to(device)
summary(big_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-4                       [100, 1024]               2,098,176
# │    └─ReLU: 2-5                         [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-6                       [100, 512]                524,800
# │    └─ReLU: 2-7                         [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-8                       [100, 256]                131,328
# │    └─ReLU: 2-9                         [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-10                      [100, 128]                32,896
# │    └─ReLU: 2-11                        [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-12                      [100, 64]                 8,256
# │    └─ReLU: 2-13                        [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-14                      [100, 32]                 2,080
# │    └─ReLU: 2-15                        [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)

# %%
train_loss_list2, train_acc_list2, valid_loss_list2, valid_acc_list2 = fit(
    train_loader, test_loader,
    big_model,
    loss_fn,
    optimizer,
    epochs,
    patience=5,
    save_best_model=False,
    device=device,
    mode='multi'
)
# Out:
# Epoch[1/100] - Train loss: 0.09345 Train Accucracy: 0.97285 || Validation Loss: 0.11487 Validation Accuracy: 0.96620
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.06420 Train Accucracy: 0.98165 || Validation Loss: 0.10549 Validation Accuracy: 0.96930
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.04947 Train Accucracy: 0.98532 || Validation Loss: 0.08949 Validation Accuracy: 0.97450
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.03384 Train Accucracy: 0.99028 || Validation Loss: 0.08217 Validation Accuracy: 0.97740
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.02671 Train Accucracy: 0.99205 || Validation Loss: 0.07911 Validation Accuracy: 0.97730
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.02759 Train Accucracy: 0.99197 || Validation Loss: 0.09153 Validation Accuracy: 0.97610
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.02931 Train Accucracy: 0.99155 || Validation Loss: 0.10001 Validation Accuracy: 0.97570
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.03606 Train Accucracy: 0.98973 || Validation Loss: 0.11231 Validation Accuracy: 0.97340
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.01387 Train Accucracy: 0.99600 || Validation Loss: 0.09089 Validation Accuracy: 0.97990
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.02240 Train Accucracy: 0.99352 || Validation Loss: 0.10453 Validation Accuracy: 0.97660
# ====================================================================================================
# Early stopping: Epoch - 9
# 210.0114061832428 초

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   Drop시킬 노드를 가진 Layer 뒤에 추가한다.

# %%
class DropoutModel(nn.Module):

    def __init__(self, drop_rate=0.2):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)

    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
dout_model = DropoutModel(drop_rate=0.5).to(device)
summary(dout_model, (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropoutModel                             [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# │    └─Dropout: 2-4                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-5                       [100, 1024]               2,098,176
# │    └─ReLU: 2-6                         [100, 1024]               --
# │    └─Dropout: 2-7                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-8                       [100, 512]                524,800
# │    └─ReLU: 2-9                         [100, 512]                --
# │    └─Dropout: 2-10                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-11                      [100, 256]                131,328
# │    └─ReLU: 2-12                        [100, 256]                --
# │    └─Dropout: 2-13                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-14                      [100, 128]                32,896
# │    └─ReLU: 2-15                        [100, 128]                --
# │    └─Dropout: 2-16                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-17                      [100, 64]                 8,256
# │    └─ReLU: 2-18                        [100, 64]                 --
# │    └─Dropout: 2-19                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-20                      [100, 32]                 2,080
# │    └─ReLU: 2-21                        [100, 32]                 --
# │    └─Dropout: 2-22                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dout_model.parameters(), lr=lr)

# %%
train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3 = fit(
    train_loader, test_loader,
    dout_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode='multi'
)
# Out:
# Epoch[1/100] - Train loss: 0.79046 Train Accucracy: 0.61102 || Validation Loss: 0.78956 Validation Accuracy: 0.61090
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.47743 Train Accucracy: 0.77647 || Validation Loss: 0.49547 Validation Accuracy: 0.77050
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.33341 Train Accucracy: 0.89497 || Validation Loss: 0.37309 Validation Accuracy: 0.88730
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.25506 Train Accucracy: 0.94908 || Validation Loss: 0.30862 Validation Accuracy: 0.94220
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.22485 Train Accucracy: 0.94593 || Validation Loss: 0.26772 Validation Accuracy: 0.93900
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.17732 Train Accucracy: 0.96062 || Validation Loss: 0.23918 Validation Accuracy: 0.95180
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.15612 Train Accucracy: 0.96270 || Validation Loss: 0.20895 Validation Accuracy: 0.95680
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.12588 Train Accucracy: 0.97300 || Validation Loss: 0.20976 Validation Accuracy: 0.96360
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.12030 Train Accucracy: 0.97185 || Validation Loss: 0.17166 Validation Accuracy: 0.96410
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.12214 Train Accucracy: 0.96935 || Validation Loss: 0.20802 Validation Accuracy: 0.95910
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.09340 Train Accucracy: 0.97748 || Validation Loss: 0.17631 Validation Accuracy: 0.96770
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.08706 Train Accucracy: 0.97845 || Validation Loss: 0.20068 Validation Accuracy: 0.96890
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.08706 Train Accucracy: 0.97825 || Validation Loss: 0.14895 Validation Accuracy: 0.97080
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.09240 Train Accucracy: 0.97585 || Validation Loss: 0.16448 Validation Accuracy: 0.96620
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.07201 Train Accucracy: 0.98240 || Validation Loss: 0.17665 Validation Accuracy: 0.97350
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.06875 Train Accucracy: 0.98215 || Validation Loss: 0.17289 Validation Accuracy: 0.97310
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.06170 Train Accucracy: 0.98465 || Validation Loss: 0.16882 Validation Accuracy: 0.97380
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.05721 Train Accucracy: 0.98623 || Validation Loss: 0.17774 Validation Accuracy: 0.97660
# ====================================================================================================
# Early stopping: Epoch - 17
# 467.93251633644104 초

# %% [markdown]
# # Batch Normalization
#
# - Dense 와 Activation 사이에 정의한다.

# %%
# nn.BatchNorm1d(입력 feature 개수)
# Linear -> BatchNorm -> ReLU(Activation)
# Linear -> BatchNorm -> ReLU(Activation) -> Dropout

class BatchNormModel(nn.Module):

    def __init__(self, drop_rate=0.2):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.BatchNorm1d(2048), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)

    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
bn_model = BatchNormModel(drop_rate=0.5).to(device)
summary(bn_model, (100, 1, 28, 28))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bn_model = BatchNormModel(drop_rate=0.5).to(device)
#       2 summary(bn_model, (100, 1, 28, 28))
#
# NameError: name 'device' is not defined

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """Learning 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0] # 눈금을 10 배수 자리에 위치.
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %% [markdown]
# #### StepLR

# %%
small_model = SmallModel()
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)

# optimizer에서 현재 LR을 조회
optim.param_groups[0]['lr']
# Out:
# 0.001

# %%
# LearningRate Scheduler - StepLR: 계단 형태로 Learning Rate를 특정 step마다 특정 비율로 줄여나간다.
steplr_scheduler = torch.optim.lr_scheduler.StepLR(
    optim, # 학습률을 변경할 옵티마이저
    step_size=30, # 몇 step(또는 epoch)마다 learning rate를 변경할지 지정 -> steplr_scheduler.step(): 지정한 step_size만큼 실행되면 lr 변경
    gamma=0.5, # 변경할 비율
)
# 30 step마다 LR를 '현재학습률 * gamma'로 변경한다.

# 현재 learning rate를 스케쥴러로부터 조회
steplr_scheduler.get_last_lr()
# Out:
# [0.001]

# %%
epochs = 300
step_size = 10
lr_list = []
for epoch in range(epochs):
    for step in range(step_size): # for x, y in dataloader: 과 같은 기능
        # 1step 학습
        # x, y device로 이동
        # 추론. p=model(x)
        # loss. loss=loss_fn(p, y)
        # grad. loss.backward()
        # grad 업데이트
        optim.step()
        # grad초기화
        optim.zero_grad()

        steplr_scheduler.step() # LR 변경 요청
        lr_list.append(steplr_scheduler.get_last_lr()) # step() 후 lr를 저장

# %%
lr_list
# Out:
# [[0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.001],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.0005],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.00025],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [0.000125],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [6.25e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [3.125e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [1.5625e-05],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [7.8125e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [3.90625e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [1.953125e-06],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [9.765625e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [4.8828125e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [2.44140625e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [1.220703125e-07],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [6.103515625e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [3.0517578125e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [1.52587890625e-08],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [7.62939453125e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [3.814697265625e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [1.9073486328125e-09],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [9.5367431640625e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [4.76837158203125e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [2.384185791015625e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [1.1920928955078125e-10],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [5.960464477539063e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [2.980232238769531e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [1.4901161193847657e-11],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [7.450580596923828e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [3.725290298461914e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [1.862645149230957e-12],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [9.313225746154785e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [4.656612873077393e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [2.3283064365386963e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  [1.1641532182693482e-13],
#  ...]

# %%
plt.rcParams['font.family'] = "malgun gothic"
plot_lr("Step LR", lr_list)

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 감소와 증가를 반복하여 진동하는 방식으로 최적점을 찾아가는 알고리즘을 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
ca_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optim,
    T_max=10, # 변화 주기 (step 또는 epoch) - '최대(초기LR)~최소 또는 최소~최대'가 한 주기임.
    eta_min=1e-6, # lr 최소값 지정
)

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        # ... 학습
        optim.step()
        optim.zero_grad()
    
    ca_lr_scheduler.step() # epoch 단위로 lr 변경 (epoch 10번 동안 lr값이 최대~최소로 움직인다.)
    lr_list.append(ca_lr_scheduler.get_last_lr())

# %%
plot_lr("ConsineAneelingLR", lr_list)

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 에폭을 점점 늘리거나 줄일 수 있다. (보통 늘린다.)

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
cawr_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optim,
    T_0=10, # 변화 주기 (위치에 따라 step 또는 epoch)
    T_mult=2, # 새로운 변화 주기(새로운 T_0) = 현재 T_0 * T_mult (한 주기가 끝날 때마다 T_0를 다시 계산)
    eta_min=1e-6
)

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        # ... 학습
        optim.step()
        optim.zero_grad()
    
    cawr_lr_scheduler.step() # epoch 단위로 lr 변경 (10번 -> 20번 -> 40번 ...)
    lr_list.append(cawr_lr_scheduler.get_last_lr())

# %%
plot_lr("ConsineAneelingWarmRestartsLR", lr_list)
